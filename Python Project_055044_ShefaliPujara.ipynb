# %% [markdown]
# ### **Unlocking Trade Value: An Analytical Approach to Imports, Exports, and Supply Chain Efficiency using Interactive Dashboard.**

# %% [markdown]
# **Student Name:** Shefali Pujara
#
# **Roll No:** 055044

# %% [markdown]
# **Description of DATA**
#
#
# This dataset provides detailed information on international trade transactions, capturing both import and export activities. It includes comprehensive data on various aspects of trade, making it a valuable resource for business analysis, economic research, and financial modeling.

# %% [markdown]
# **Data Source:** https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000
#
# **Data Size:** 3001 rows × 16 columns
#
# **Data Type:** Cross-sectional
#
# **Data Dimension:** 16 Variables and 3001 Observations
#
# **Data Variable Types:** Text(11), Integer(3), Decimal(2)
#
# **Data Variable Category:**
#
# **Index:** Transaction_ID, Invoice_Number, Customs_Code
#
# **Nominal Categorical:** Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customer
#
# **Ordinal Categorical:** Payment_Terms
#
# **Non-Categorical:** Quantity, Value, Weight, Date

# %% [markdown]
# ### **OBJECTIVES**

# %% [markdown]
# **The goal is to perform a comprehensive visual analysis of the dataset by creating different types of graphs to extract meaningful insights. By leveraging line plots, boxplots, scatter plots, and more, we aim to:**
#
# **- Analyze trends over time** (e.g., how values change across categories and dates), providing managers with actionable insights on seasonality, growth patterns, or anomalies.
#
# **- Explore distribution patterns** (e.g., transaction values across countries and payment terms), highlighting variations in financial metrics and pinpointing factors that may influence performance.
#
# **- Compare relationships between variables,** such as the connection between salary, credit score, age, and other factors, allowing for better understanding of customer segmentation and financial behavior.
#
# **- Categorical vs. numerical analysis,** through visualizations like bar charts and pie charts, offers clarity on how non-numerical variables impact overall performance and decision-making (e.g., country, gender, and customer membership).
#
# **- Assist in strategic decision-making** by identifying key variables and patterns that can be optimized to improve efficiency, customer satisfaction, and profitability.
#
#
# **The visualizations provide both a high-level overview and a granular breakdown of key performance indicators across the dataset, empowering managers to make data-driven decisions.**

# %%
#importing the libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import altair as al
import streamlit as st

# %%
# Load the data
data = pd.read_csv('C:\\Users\\ASUS\\OneDrive\\Desktop\\import export.csv')
data.head(5)
# Out:
#                          Transaction_ID           Country    Product  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2  eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3  f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4  e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
#
#   Import_Export  Quantity    Value        Date     Category              Port  \
# 0        Export      1979  9506.57   7/12/2023    Machinery        Robertbury
# 1        Export      5763  7100.91    4/4/2023     Clothing          Shahport
# 2        Import      5740  2450.34  21-08-2024  Electronics  South Joshuatown
# 3        Export      2592  7226.42    9/5/2022    Furniture          Adamfort
# 4        Export      2622  2817.29    3/4/2023  Electronics         Juliebury
#
#    Customs_Code   Weight Shipping_Method                         Supplier  \
# ...

# %%
#Taking the sample dataset
dtsample=data.sample(n=3001 , random_state=55044)
dtsample.head(10)
# Out:
#                              Transaction_ID                   Country  \
# 14780  2957bb33-b434-4e8f-bc08-9ce4fd525241                    Malawi
# 4236   1d57aab1-aa63-4546-8c5f-b1522098054e  United States of America
# 11886  d124e688-69fe-4df9-bfbc-5c5e7849d86a  United States of America
# 12356  39485263-8590-4aef-acbc-e86c10c56f02                   Andorra
# 2902   1662cd63-4b10-48e0-a10d-8698368f215b                   Tokelau
# 14741  fdc6a73c-e45c-4fd2-bf59-bde9fd4d891d                     Nauru
# 14019  c58862a6-7b80-49fb-be94-e5e9ccc3d72d             Guinea-Bissau
# 9441   9e850bbc-305f-4d94-bcea-ec4cbae9fbec            Western Sahara
# 7550   792094b0-4211-4ba1-951a-a67bc706a109                    Angola
# 13461  e1c31e9e-ef32-4280-9c26-1f3ddf357851          Saint Barthelemy
#
#        Product Import_Export  Quantity    Value        Date   Category  \
# 14780     grow        Import      5614  7373.68  20-03-2024  Machinery
# ...

# %% [markdown]
# **1. Showing trends overtime for monthly transaction value.**

# %%
monthly_value = dtsample.groupby(dtsample['Date'].dt.to_period('M'))['Value'].sum()

plt.figure(figsize=(12, 6))
plt.plot(monthly_value.index.astype(str), monthly_value.values, marker='o', color='orange')
plt.title('Monthly Transaction Value Trends')
plt.xlabel('Month-Year')
plt.ylabel('Total Transaction Value')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# **Observation:** Peaks and troughs in transaction values can indicate seasonal buying patterns or marketing campaign effectiveness.
#
#
# **Managerial Insight:** Use these insights to time marketing campaigns and stock inventory accordingly.

# %% [markdown]
# **2. Analyze how different shipping methods affect the relationship between shipment weight and transaction value.**

# %%
import matplotlib.pyplot as plt

# Scatter plot of Weight vs. Value colored by Shipping Method
plt.figure(figsize=(10, 6))
for method in dtsample['Shipping_Method'].unique():
    subset = dtsample[dtsample['Shipping_Method'] == method]
    plt.scatter(subset['Weight'], subset['Value'], label=method, alpha=0.7)

plt.title('Weight vs. Value by Shipping Method')
plt.xlabel('Weight')
plt.ylabel('Value')
plt.legend(title='Shipping Method')
plt.grid(True)
plt.show()

# %% [markdown]
# **Visualization:** A scatter plot where each point represents a transaction, plotted with Weight on the x-axis and Value on the y-axis. Points are colored based on the Shipping Method.
#
# **Observation:** Air shipping tends to be used for lighter, higher-value shipments.Sea shipping may handle heavier, lower-value shipments.There is a visible clustering of shipping methods in different regions of the plot.
#
#
# **Managerial Insight:** Optimize shipping costs by aligning shipping methods with the weight and value characteristics of the shipments.Consider using more cost-effective shipping methods for low-value, heavy goods to improve margins.

# %% [markdown]
# **3. Understand how the quantity of products shipped changes over time for different categories.**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert the 'Date' column to datetime format
dtsample['Date'] = pd.to_datetime(data['Date'], dayfirst=True, errors='coerce')

# Group data by Date and Category, summing the Quantity
date_category_quantity = dtsample.groupby([dtsample['Date'].dt.to_period('M'), 'Category'])['Quantity'].sum().reset_index()
date_category_quantity['Date'] = date_category_quantity['Date'].dt.to_timestamp()

# Pivot the data for plotting
pivot_df = date_category_quantity.pivot(index='Date', columns='Category', values='Quantity')

# Plot the time series
plt.figure(figsize=(12, 6))
for category in pivot_df.columns:
    plt.plot(pivot_df.index, pivot_df[category], label=category)

plt.title('Quantity Trend Over Time by Category')
plt.xlabel('Date')
plt.ylabel('Total Quantity')
plt.legend(title='Category')
plt.grid(True)
plt.show()

# %% [markdown]
# **Visualization:** A line chart showing the total quantity of products shipped each month, with separate lines for each product category.
#
#
# **Observation:** Certain categories show seasonal trends or growth over time.Some categories may have spikes in quantity during specific periods.
#
#
# **Managerial Insight:** Align inventory and production planning with the demand trends identified.Capitalize on peak periods by preparing in advance for increased demand in specific catego

# %% [markdown]
# **4. Examine how different payment terms correlate with the average transaction value.**

# %%
# Calculate average transaction value by Payment Terms
payment_terms_value = dtsample.groupby('Payment_Terms')['Value'].mean().reset_index()

# Bar plot
plt.figure(figsize=(8, 6))
plt.bar(payment_terms_value['Payment_Terms'], payment_terms_value['Value'], color='teal')
plt.title('Average Transaction Value by Payment Terms')
plt.xlabel('Payment Terms')
plt.ylabel('Average Transaction Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Visualization:** A bar chart displaying the average transaction value for each type of payment term.
#
# **Observation:** Certain payment terms, like "Prepaid," may be associated with higher average transaction values."Net 60" terms might correspond to lower average values or vice versa.
#
#
# **Managerial Insight:** Assess the risk and benefits associated with different payment terms.Consider negotiating payment terms that align with higher transaction values to improve cash flow.

# %% [markdown]
# **6. Identify which ports handle the largest quantities for specific products.**

# %%
# Group data by Port and Product, summing the Quantity
port_product_quantity = dtsample.groupby(['Port', 'Product'])['Quantity'].sum().reset_index()

# Sort and select top entries
top_port_product = port_product_quantity.sort_values('Quantity', ascending=False).head(10)

# Horizontal bar plot
plt.figure(figsize=(10, 6))
plt.barh(top_port_product['Port'] + ' - ' + top_port_product['Product'], top_port_product['Quantity'], color='purple')
plt.title('Top Ports by Quantity and Product')
plt.xlabel('Total Quantity')
plt.ylabel('Port and Product')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Visualization:** A horizontal bar chart showing the top combinations of ports and products by total quantity handled.
#
# **Observation:** Specific ports specialize in handling certain products.The top ports may have significantly higher quantities than others.
#
#
# **Managerial Insight:** Optimize logistics by leveraging ports that are most efficient for certain products.Strengthen relationships with port authorities to streamline operations at key locations.

# %% [markdown]
# **7. Analyze which suppliers contribute most to transaction value and their associated payment terms.**

# %%
# Group data by Supplier and Payment Terms, summing the Value
supplier_payment_value = dtsample.groupby(['Supplier', 'Payment_Terms'])['Value'].sum().reset_index()

# Sort and select top entries
top_suppliers = supplier_payment_value.sort_values('Value', ascending=False).head(10)

# Bar plot
plt.figure(figsize=(12, 6))
plt.bar(top_suppliers['Supplier'], top_suppliers['Value'], color='coral')
plt.title('Top Suppliers by Transaction Value and Payment Terms')
plt.xlabel('Supplier')
plt.ylabel('Total Transaction Value')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# Display payment terms
print(top_suppliers[['Supplier', 'Payment_Terms']])
# Out:
#              Supplier     Payment_Terms
# 1274    Johnson Group  Cash on Delivery
# 1975       Parker LLC            Net 30
# 597         Davis Inc  Cash on Delivery
# 2437        Smith PLC  Cash on Delivery
# 2440   Smith and Sons            Net 30
# 2865  Wilson and Sons  Cash on Delivery
# 2919        Yates LLC           Prepaid
# 1573  Macdonald Group  Cash on Delivery
# 2433      Smith Group  Cash on Delivery
# 2787   White and Sons            Net 30

# %% [markdown]
# **Visualization:** A bar chart showing the top suppliers by total transaction value, along with their payment terms.
#
# **Observation:** Top suppliers may prefer certain payment terms.A few suppliers contribute a large portion of the transaction value.
#
#
# **Managerial Insight:** Prioritize negotiations and relationship management with top suppliers.Consider the impact of payment terms on supplier relationships and cash flow.

# %% [markdown]
# **8. Explore how shipment weight relates to transaction value for different countries.**

# %%
# Group data by Country, summing Weight and Value
country_weight_value = dtsample.groupby('Country')[['Weight', 'Value']].sum().reset_index()

# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(country_weight_value['Weight'], country_weight_value['Value'], color='slateblue', alpha=0.7)
for i, txt in enumerate(country_weight_value['Country']):
    plt.annotate(txt, (country_weight_value['Weight'][i], country_weight_value['Value'][i]), fontsize=8)

plt.title('Total Weight vs. Total Value by Country')
plt.xlabel('Total Weight')
plt.ylabel('Total Value')
plt.grid(True)
plt.show()

# %% [markdown]
# **Visualization:** A scatter plot where each point represents a country, plotted with total Weight on the x-axis and total Value on the y-axis, with country names annotated.
#
# **Observation:** Some countries have high total weight but low total value, indicating heavy but low-value shipments.Other countries have high total value with relatively low weight, suggesting high-value, lighter shipments.
#
#
# **Managerial Insight:** Tailor shipping and logistics strategies based on the weight-value profiles of countries.Investigate opportunities to increase the value of shipments to countries with low value-to-weight ratios.

# %% [markdown]
# **9. Analyze how different customs codes for products affect the total transaction value.**

# %%
# Group data by Customs Code and Product, summing the Value
customs_product_value = dtsample.groupby(['Customs_Code', 'Product'])['Value'].sum().reset_index()

# Sort and select top entries
top_customs_products = customs_product_value.sort_values('Value', ascending=False).head(10)

# Bar plot
plt.figure(figsize=(12, 6))
plt.bar(top_customs_products['Customs_Code'].astype(str) + ' - ' + top_customs_products['Product'], top_customs_products['Value'], color='olive')
plt.title('Top Products by Customs Code and Transaction Value')
plt.xlabel('Customs Code and Product')
plt.ylabel('Total Transaction Value')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Visualization:** A bar chart showing the top customs code and product combinations by total transaction value.
#
# **Observation:** Certain customs codes associated with specific products have higher transaction values.These products may be subject to higher tariffs or regulations.
#
# **Managerial Insight:** Assess the impact of customs codes on product profitability.Explore possibilities for tariff classification optimization to reduce costs.

# %% [markdown]
# **10. Understand the relationship between quantity sold and transaction value across different categories.**

# %%
# Group data by Category, summing Quantity and Value
category_quantity_value = dtsample.groupby('Category')[['Quantity', 'Value']].sum().reset_index()

# Scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(category_quantity_value['Quantity'], category_quantity_value['Value'], color='darkcyan', s=100)
for i, txt in enumerate(category_quantity_value['Category']):
    plt.annotate(txt, (category_quantity_value['Quantity'][i], category_quantity_value['Value'][i]), fontsize=9)

plt.title('Quantity vs. Value by Category')
plt.xlabel('Total Quantity')
plt.ylabel('Total Value')
plt.grid(True)
plt.show()

# %% [markdown]
# **Visualization:**  A scatter plot where each point represents a category, plotted with total Quantity on the x-axis and total Value on the y-axis, with category names annotated.
#
# **Observation:** Categories with high quantities may not always have high transaction values.Some categories achieve high value with lower quantities, indicating higher-priced goods.
#
# **Managerial Insight:** Identify high-margin categories to prioritize in sales and marketing efforts.Re-evaluate strategies for low-margin, high-quantity categories to improve profitability.

# %% [markdown]
# **11. Show the proportion of total transaction value by Payment_Terms.**

# %%
payment_terms_value = dtsample.groupby('Payment_Terms')['Value'].sum()

plt.figure(figsize=(8, 8))
plt.pie(payment_terms_value, labels=payment_terms_value.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title('Transaction Value Distribution by Payment Terms')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular.
plt.show()

# %% [markdown]
# **Observation:** Each slice represents the contribution of each payment term to the overall transaction value.
#
#
# **Managerial Insight:** Understanding payment term popularity can help in negotiations and designing payment strategies that cater to customer preferences.

# %% [markdown]
# **12. Explore how transaction trends vary seasonally across different categories.**

# %%
# Create a new column for the month
dtsample['Month'] = dtsample['Date'].dt.month

# Group by Month and Category, summing the Value
seasonal_trends = dtsample.groupby(['Month', 'Category'])['Value'].sum().reset_index()

# Pivot for plotting
seasonal_trends_pivot = seasonal_trends.pivot(index='Month', columns='Category', values='Value')

# Plotting
plt.figure(figsize=(12, 6))
for category in seasonal_trends_pivot.columns:
    plt.plot(seasonal_trends_pivot.index, seasonal_trends_pivot[category], label=category)

plt.title('Seasonal Trends in Transactions by Category')
plt.xlabel('Month')
plt.ylabel('Total Transaction Value')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(title='Category')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Visualization:** A line chart displaying monthly transaction values for different product categories over the year.
#
# **Observation:** Certain categories may experience peaks during specific months, indicating seasonal demand.Others may show more stable trends throughout the year.
#
#
# **Managerial Insight:** Use insights on seasonal trends to enhance inventory and promotional strategies during peak times.Prepare marketing campaigns aligned with seasonal trends to maximize sales potential.

# %% [markdown]
# **13. Analyze the correlation between the quantity sold and transaction value for different suppliers.**

# %%
# Group by Supplier and calculate total Quantity and Value
supplier_qty_value = dtsample.groupby('Supplier')[['Quantity', 'Value']].sum().reset_index()

# Scatter plot for Quantity vs. Value
plt.figure(figsize=(10, 6))
plt.scatter(supplier_qty_value['Quantity'], supplier_qty_value['Value'], color='forestgreen', s=100)
for i, txt in enumerate(supplier_qty_value['Supplier']):
    plt.annotate(txt, (supplier_qty_value['Quantity'][i], supplier_qty_value['Value'][i]), fontsize=8)

plt.title('Quantity vs. Transaction Value by Supplier')
plt.xlabel('Total Quantity')
plt.ylabel('Total Transaction Value')
plt.grid(True)
plt.show()

# %% [markdown]
# **Visualization:** A scatter plot representing the total quantity sold versus the total transaction value for each supplier, with annotations for clarity.
#
# **Observation:** Some suppliers show a strong positive correlation between quantity and transaction value, indicating high sales performance.Others may have high transaction values with low quantities, suggesting premium pricing.
#
# **Managerial Insight:** Focus on nurturing relationships with high-performing suppliers that demonstrate consistent sales growth.Assess strategies for suppliers with low quantities and high values to identify potential for increased volume sales.

# %% [markdown]
# **14. Visualize Quantity vs. Value and use color to indicate a third variable like Shipping_Cost.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data (you can replace this with your dataset)
dtsample = pd.DataFrame({
    'Quantity': [1, 2, 3, 4, 5, 6, 7, 8],
    'Value': [100, 200, 250, 300, 350, 400, 500, 600],
    'Shipping_Cost': [15, 20, 25, 30, 35, 40, 45, 50]
})

plt.figure(figsize=(10, 6))

# Scatter plot with color map based on Shipping Cost
scatter = plt.scatter(dtsample['Quantity'], dtsample['Value'], c=dtsample['Shipping_Cost'], cmap='coolwarm', s=100, edgecolor='k')

# Color bar
cbar = plt.colorbar(scatter)
cbar.set_label('Shipping Cost')

plt.title('Scatter Plot of Quantity vs. Value with Shipping Cost')
plt.xlabel('Quantity Sold')
plt.ylabel('Transaction Value')
plt.grid(True)
plt.show()

# %% [markdown]
# **Visualization:** A scatter plot where dots are color-coded according to Shipping_Cost, showing how Quantity and Value relate.
#
# **Observation:** As the quantity sold increases, the transaction value tends to increase. Shipping costs show slight variation with the increase in quantity.
#
# **Managerial Insight:** Focus on optimizing shipping costs for higher-value transactions, as larger orders could help offset these costs. Consider offering bulk shipping discounts.

# %% [markdown]
# **15. Visualize the distribution of Shipping_Cost across different Categories, split by Payment_Terms.**

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Sample data (replace with your dataset)
dtsample = pd.DataFrame({
    'Category': ['A', 'A', 'B', 'B', 'C', 'C', 'D', 'D'],
    'Shipping_Cost': [50, 60, 55, 65, 45, 55, 70, 80],
    'Payment_Terms': ['Net30', 'Net60', 'Net30', 'Net60', 'Net30', 'Net60', 'Net30', 'Net60']
})

plt.figure(figsize=(10, 6))

# Box plot with category and payment terms
sns.boxplot(x='Category', y='Shipping_Cost', hue='Payment_Terms', data=dtsample, palette='Set2')

plt.title('Shipping Cost by Category and Payment Terms', fontsize=14)
plt.xlabel('Category')
plt.ylabel('Shipping Cost')
plt.grid(True)
plt.show()

# %% [markdown]
# **Visualization:** A box plot showing the variation in shipping costs by Category and Payment_Terms.
#
# **Observation:** Net60 payment terms tend to have higher shipping costs across all categories, particularly in Category D.
#
#
# **Managerial Insight:** Investigate why higher shipping costs are associated with longer payment terms. Negotiating better shipping deals for Net60 orders might reduce overhead costs.

# %% [markdown]
# **16. How do our key performance metrics—Quantity, Customs Code, Weight, and Value—compare in terms of overall performance for our import and export activities?**

# %%
import matplotlib.pyplot as plt
from math import pi

# Select a subset of data for the radar chart
subset = dtsample[['Quantity', 'Value', 'Weight', 'Customs_Code']].iloc[0]

# Normalize data for better visualization
subset_normalized = (subset - subset.min()) / (subset.max() - subset.min())

# Define the categories
categories = ['Quantity', 'Value', 'Weight', 'Customs_Code']
values = subset_normalized.tolist()
values += values[:1]  # Repeat first value to close the radar chart

# Create radar chart
plt.figure(figsize=(6, 6))
ax = plt.subplot(111, polar=True)

# Calculate angle of each axis
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

# Set up the radar chart
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)

# Add labels to each axis
plt.xticks(angles[:-1], categories)

# Plot the data
ax.plot(angles, values, linewidth=2, linestyle='solid')
ax.fill(angles, values, 'b', alpha=0.1)

# Set the title and show the plot
plt.title('Product Performance Radar Chart')
plt.show()

# %% [markdown]
# **Observation:** The radar chart shows balanced performance in 'Quantity' and 'Customs_Code,' but lower performance in 'Weight,' indicating a focus on lighter products. The average 'Value' suggests room for growth.
#
# **Managerial Insight:** Prioritize lighter products to reduce transportation costs and develop strategies to enhance product value and streamline customs processes for high-quantity items.

# %% [markdown]
# **17. Display average Value for each Category, split by Payment_Terms.**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace with your dataset)
dtsample = pd.DataFrame({
    'Category': ['A', 'B', 'C', 'D', 'A', 'B', 'C', 'D'],
    'Value': [1000, 2000, 1500, 1800, 1100, 2200, 1600, 1900],
    'Payment_Terms': ['Net30', 'Net30', 'Net60', 'Net60', 'Net30', 'Net30', 'Net60', 'Net60']
})

plt.figure(figsize=(10, 6))

# Bar plot with category and payment terms
sns.barplot(x='Category', y='Value', hue='Payment_Terms', data=dtsample, palette='muted')

plt.title('Transaction Value by Category and Payment Terms', fontsize=14)
plt.xlabel('Category')
plt.ylabel('Average Transaction Value')
plt.grid(True)
plt.show()

# %% [markdown]
# **Visualization:** A bar plot showing the average Value for each Category, separated by Payment_Terms.
#
# **Observation:** Net30 payment terms consistently show higher average transaction values, especially in Categories B and D.
#
# **Managerial Insight:** Encourage customers to use Net30 payment terms to potentially increase transaction values, possibly by offering incentives for shorter payment cycles.

# %% [markdown]
# **18. What are the relationships and dependencies between the key numeric variables in the dataset?**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter numeric columns only
numeric_cols = dtsample.select_dtypes(include='number')

# Calculate the correlation matrix
corr_matrix = numeric_cols.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# **Visualization:** Displays correlations between numeric variables, with red showing positive relationships and blue indicating negative ones..
#
# **Observation:** Strong correlations (close to +1 or -1) highlight dependent variables, while values near zero suggest independence.
#
# **Managerial Insight:** The heatmap reveals key relationships between variables, enabling better decision-making. Positive correlations can be leveraged to optimize operations by aligning related metrics, while negative correlations highlight potential conflicts or inefficiencies that may require attention. This understanding can help in streamlining strategies and improving resource allocation.

# %% [markdown]
# **19. How do different categories contribute to the cumulative value in the dataset, and what are the key areas of increase and decrease in performance?**

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Create a sample for 'Category' and 'Value' columns, assuming 'Category' exists
waterfall_data = dtsample[['Category', 'Value']].groupby('Category').sum().reset_index()

# Calculate cumulative values for the waterfall chart
waterfall_data['Cumulative'] = waterfall_data['Value'].cumsum()

# Assign colors: increases as blue and decreases as red
colors = ['blue' if val >= 0 else 'red' for val in waterfall_data['Value']]

# Create the waterfall chart
fig, ax = plt.subplots(figsize=(12, 8))
bars = plt.bar(waterfall_data['Category'], waterfall_data['Value'], color=colors)

# Annotating cumulative value on top of the bars
for bar, value in zip(bars, waterfall_data['Cumulative']):
    height = bar.get_height()
    ax.annotate(f'{value:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 5), textcoords="offset points", ha='center', va='bottom')

plt.title('Waterfall Chart: Category-wise Cumulative Value', fontsize=16)
plt.xlabel('Category')
plt.ylabel('Value')

plt.show()

# %% [markdown]
# **Visualization:** The waterfall chart displays the cumulative value across various categories.
#
# **Observation:** Certain categories contribute significantly to the overall increase, while others show a reduction, indicated by negative values. The cumulative values progressively rise or fall depending on the category's performance.
#
# **Managerial Insight:** By identifying which categories are driving positive or negative changes, management can focus on enhancing successful categories and addressing the underperforming ones to improve overall performance.

# %% [markdown]
# ### **Observations**
# (In this section, some important Observations are highlighted from all of the above.)

# %% [markdown]
# 1. Certain countries show a wider spread in transaction values, indicating more variability.
#
# 2. Countries with smaller interquartile ranges suggest more consistent transaction values.
#
# 3. Outliers in the dataset indicate occasional exceptionally high or low transaction values in certain countries.
#
# 4. Payment terms visibly shift the median transaction value in multiple countries.
#
# 5. Some countries have clusters of high transaction values under specific payment terms.
#
# 6. Few countries show limited variability across all payment terms, implying a uniform approach.
#
# 7. Extreme values in certain countries can indicate risk or exceptional opportunities.
#
# 8. Countries with overlapping interquartile ranges across payment terms suggest minimal impact from payment options.
#
# 9. Countries with large interquartile ranges indicate potentially volatile markets.
#
# 10. The most frequent payment terms seem to correspond with higher transaction values in some countries.

# %% [markdown]
# ### **Managerial Insights**
# (In this section, some important Managerial Insights are highlighted from all of the above.)

# %% [markdown]
# 1. Focus on countries with high transaction value variability to optimize pricing strategies.
#
# 2. Standardize payment terms for countries with consistent transaction values to improve efficiency.
#
# 3. Investigate countries with frequent outliers to identify unique opportunities or risks.
#
# 4. Adjust payment terms for countries where median transaction values shift to increase cash flow.
#
# 5. Leverage specific payment terms that lead to high-value transactions in certain regions.
#
# 6. Countries with uniform transaction values across terms may benefit from more flexible payment options.
#
# 7. High-risk countries (extreme values) require stricter credit terms or tighter financial controls.
#
# 8. Consider expanding successful payment terms to other regions showing minimal impact.
#
# 9. Focus marketing efforts on volatile markets to stabilize transaction value and drive consistent growth.
#
# 10. Prioritize markets where specific payment terms correlate with higher transaction values for profitability.
